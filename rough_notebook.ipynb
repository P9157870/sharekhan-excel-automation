# %% [markdown]
# #### importing libraries

# %%
import pandas as pd
import xlsxwriter
import datetime
import yfinance as yf

# %% [markdown]
# <h4>Reading data from Master file and classify</h4>

# %%
excel_file = r"Master Stock Data.xlsx"
df = pd.read_excel(excel_file,engine='openpyxl')
buy_df = df[df['Buy/Sell'] == 'B'].reset_index(drop=True)
sell_df = df[df['Buy/Sell'] == 'S'].reset_index(drop=True)
#buy_df

# %% [markdown]
# #### initialising sample resultant_df

# %%
resultant_df =  pd.DataFrame(columns = [
    "S.No",
    "Entry Date",       #? Trade Date aka Buy date in Equity Tradelisting sheet
    "Stocks",           #? Scrip Symbol - E.g : AJANTPHARM
    "Transaction",      #? Buy or Sell - here in this column, it's BUY only
    "Buy Quantity",     #? Buying Quantity  - column F  in BUY Category 
    "Entry Price",      #? Rate - Column G in BUY Category
    "Buy Cost",         #? Brokerage + (IGST + SGST + CGST + UTGST + Cess + Stamp + TO Charges + Sebi Fees + STT Amount)
    "Buy Value",        #? Buy Quantity * Entry Price + Buy Cost
    
    "Exit Date",        #? Sell Date in respective Sell Category --> look at immediate sold stock for respective stock
    "Sell Quantity",    #? Sell Quantity (need not be same as entry)
    "Exit Price",       #? Rate - Column G in SELL Category
    "Sell Cost",        #? Brokerage + (IGST + SGST + CGST + UTGST + Cess + Stamp + TO Charges + Sebi Fees + STT Amount)
    "Sell value",       #? Sell Quantity * Exit Price + Sell Cost
    
    "PNL",              #? Profit or Loss : Exit Price - Entry Price
    "Net PNL",          #? Sell Value - Buy Value
    "Percentage",       #? Net PNL / Buy Value
    "Cumulative Profit",#? We have to sum the Net PNL for every past row and current row and make that as CP
])

# %% [markdown]
# #### adding initial buy data to resultant_df

# %%
resultant_df["Entry Date"] = buy_df["Trade Date"]
resultant_df["Stocks"] = buy_df["Scrip Symbol"]
resultant_df["Transaction"] = "Buy"
resultant_df["Buy Quantity"] = buy_df["Quantity"]
resultant_df["Entry Price"] = buy_df["Rate"]
resultant_df["Buy Cost"] = buy_df["Brokerage"] + buy_df["IGST"] + buy_df["SGST"] + buy_df["CGST"]\
                            + buy_df["UTGST"] + buy_df["Cess"] + buy_df["Stamp"] + buy_df["TO Charges"] + buy_df["Sebi Fees"]\
                            + buy_df["STT Amount"]
resultant_df["Buy Value"] = (resultant_df["Buy Quantity"] * resultant_df["Entry Price"]) + resultant_df["Buy Cost"]

# %% [markdown]
# #### function for one buy and one sell

# %%
def fill_data_for_single_buy_single_sell(stock, individual_stock_sell_df):
    temp_sell_df    = individual_stock_sell_df.iloc[0]
    exit_date       = temp_sell_df["Trade Date"]
    sell_quantity   = temp_sell_df["Quantity"]
    exit_price      = temp_sell_df["Rate"]
    sell_cost       = temp_sell_df["Brokerage"] + temp_sell_df["IGST"] + temp_sell_df["SGST"] + temp_sell_df["CGST"]\
                        + temp_sell_df["UTGST"] + temp_sell_df["Cess"] + temp_sell_df["Stamp"] + temp_sell_df["TO Charges"]\
                        + temp_sell_df["Sebi Fees"] + temp_sell_df["STT Amount"]
                    
    resultant_df.loc[resultant_df['Stocks'] == stock,
                    [
                    "Exit Date",
                    "Sell Quantity",
                    "Exit Price",
                    "Sell Cost"
                    ]
                ] = [
                        exit_date,
                        sell_quantity,
                        exit_price,
                        sell_cost
                    ]

# %% [markdown]
# #### code till single buy and single sell

# %%
total_stock_types = list(set(resultant_df["Stocks"].to_list()))

for stock in total_stock_types:
    individual_stock_buy_df = resultant_df[resultant_df["Stocks"] == stock]
    if len(individual_stock_buy_df) == 1:
        individual_stock_sell_df = sell_df[sell_df["Scrip Symbol"] == stock]
        if len(individual_stock_sell_df) == 1:
            if individual_stock_buy_df.iloc[0]["Buy Quantity"] == individual_stock_sell_df.iloc[0]["Quantity"]:
                fill_data_for_single_buy_single_sell(stock,individual_stock_sell_df)

# %%
resultant_df
# Out:
#    S.No Entry Date      Stocks Transaction  Buy Quantity  Entry Price  \
# 0   NaN 2020-02-10  AJANTPHARM         Buy            36      1370.00
# 1   NaN 2020-02-25  AJANTPHARM         Buy            40      1370.00
# 2   NaN 2020-02-04       AMBER         Buy            31      1595.00
# 3   NaN 2020-02-07      APLLTD         Buy            77       649.64
# 4   NaN 2019-10-18  BAJFINANCE         Buy            77      4132.00
# 5   NaN 2020-03-03    BANKBEES         Buy            77       297.45
# 6   NaN 2020-01-21  CANFINHOME         Buy            77       414.80
# 7   NaN 2020-01-20       CUPID         Buy            77       257.19
# 8   NaN 2019-10-09       DABUR         Buy            77       443.60
# 9   NaN 2020-02-26   DEEPAKNTR         Buy            77       509.97
# 10  NaN 2020-01-23    DFMFOODS         Buy            77       284.50
# 11  NaN 2020-02-25   GUJGASLTD         Buy            77       291.90
# 12  NaN 2019-08-16    HDFCBANK         Buy            77      2225.79
# 13  NaN 2019-10-18  HINDUNILVR         Buy            77      2106.35
# 14  NaN 2020-01-23         IGL         Buy            77       486.40
# 15  NaN 2019-08-16  INDUSINDBK         Buy            77      1425.00
# 16  NaN 2019-10-18   KANSAINER         Buy            77       540.00
# 17  NaN 2020-01-21         KEI         Buy            77       542.53
# 18  NaN 2019-08-19          LT         Buy            77      1358.40
# 19  NaN 2019-12-13          LT         Buy            77      1304.60
# 20  NaN 2020-03-05        MFSL         Buy            77       604.95
# 21  NaN 2020-02-17  MUTHOOTFIN         Buy            77       811.75
# 22  NaN 2020-02-26      NEOGEN         Buy            77       535.35
# 23  NaN 2020-01-22    NIITTECH         Buy            77      1838.00
# 24  NaN 2019-09-24  PIDILITIND         Buy            77      1459.00
# 25  NaN 2020-01-31      RELAXO         Buy            77       737.25
# 26  NaN 2019-10-18    RELIANCE         Buy            77      1418.00
# 27  NaN 2020-02-17    SYMPHONY         Buy            77      1384.44
# 28  NaN 2020-02-04         VBL         Buy            77       817.87
# 29  NaN 2020-02-04         VBL         Buy            77       817.87
# 30  NaN 2020-02-19       VMART         Buy            77      2370.72
# 31  NaN 2020-02-25  AJANTPHARM         Buy            40      1370.00
#
#     Buy Cost  Buy Value            Exit Date Sell Quantity Exit Price  \
# 0     199.76   49519.76                  NaN           NaN        NaN
# 1     199.76   54999.76                  NaN           NaN        NaN
# 2     200.26   49645.26  2020-02-17 00:00:00            31     1516.0
# 3     202.60   50224.88  2020-02-24 00:00:00            77      643.5
# 4     200.79  318364.79                  NaN           NaN        NaN
# 5     154.31   23057.96                  NaN           NaN        NaN
# 6     201.58   32141.18  2020-01-22 00:00:00            77      477.2
# 7     202.05   20005.68  2020-01-22 00:00:00            77     228.25
# 8     203.13   34360.33  2020-02-17 00:00:00            77     501.68
# 9     202.37   39470.06                  NaN           NaN        NaN
# 10    201.64   22108.14  2020-01-30 00:00:00            77      323.4
# 11    202.14   22678.44  2020-02-27 00:00:00            77      278.7
# 12    198.33  171584.16  2019-12-04 00:00:00            77    1244.15
# 13    196.18  162385.13                  NaN           NaN        NaN
# 14    200.91   37653.71  2020-02-07 00:00:00            77     504.75
# 15    202.00  109927.00  2019-10-07 00:00:00            77     1239.1
# 16    201.17   41781.17                  NaN           NaN        NaN
# 17    202.11   41976.92  2020-02-04 00:00:00            77     545.95
# 18    203.65  104800.45                  NaN           NaN        NaN
# 19    206.13  100660.33                  NaN           NaN        NaN
# 20    203.46   46784.61                  NaN           NaN        NaN
# 21    203.82   62708.57                  NaN           NaN        NaN
# 22    201.61   41423.56                  NaN           NaN        NaN
# 23    200.99  141726.99  2020-01-23 00:00:00            77    2008.15
# 24    200.90  112543.90                  NaN           NaN        NaN
# 25    203.14   56971.39  2020-02-25 00:00:00            77     791.15
# 26    200.98  109386.98  2020-01-30 00:00:00            77     1460.0
# 27    201.83  106803.71  2020-02-25 00:00:00            77     1337.1
# 28     16.92   62992.91                  NaN           NaN        NaN
# 29    202.06   63178.05                  NaN           NaN        NaN
# 30    201.61  182747.05                  NaN           NaN        NaN
# 31    199.76   54999.76                  NaN           NaN        NaN
#
#    Sell Cost Sell value  PNL Net PNL Percentage Cumulative Profit
# 0        NaN        NaN  NaN     NaN        NaN               NaN
# 1        NaN        NaN  NaN     NaN        NaN               NaN
# 2     190.33        NaN  NaN     NaN        NaN               NaN
# 3     200.68        NaN  NaN     NaN        NaN               NaN
# 4        NaN        NaN  NaN     NaN        NaN               NaN
# 5        NaN        NaN  NaN     NaN        NaN               NaN
# 6      231.9        NaN  NaN     NaN        NaN               NaN
# 7     179.32        NaN  NaN     NaN        NaN               NaN
# 8     229.58        NaN  NaN     NaN        NaN               NaN
# 9        NaN        NaN  NaN     NaN        NaN               NaN
# 10    229.24        NaN  NaN     NaN        NaN               NaN
# 11    193.13        NaN  NaN     NaN        NaN               NaN
# 12    221.69        NaN  NaN     NaN        NaN               NaN
# 13       NaN        NaN  NaN     NaN        NaN               NaN
# 14    208.49        NaN  NaN     NaN        NaN               NaN
# 15    175.71        NaN  NaN     NaN        NaN               NaN
# 16       NaN        NaN  NaN     NaN        NaN               NaN
# 17    203.41        NaN  NaN     NaN        NaN               NaN
# 18       NaN        NaN  NaN     NaN        NaN               NaN
# 19       NaN        NaN  NaN     NaN        NaN               NaN
# 20       NaN        NaN  NaN     NaN        NaN               NaN
# 21       NaN        NaN  NaN     NaN        NaN               NaN
# 22       NaN        NaN  NaN     NaN        NaN               NaN
# 23    219.58        NaN  NaN     NaN        NaN               NaN
# 24       NaN        NaN  NaN     NaN        NaN               NaN
# 25    217.85        NaN  NaN     NaN        NaN               NaN
# 26    206.99        NaN  NaN     NaN        NaN               NaN
# 27    194.93        NaN  NaN     NaN        NaN               NaN
# 28       NaN        NaN  NaN     NaN        NaN               NaN
# 29       NaN        NaN  NaN     NaN        NaN               NaN
# 30       NaN        NaN  NaN     NaN        NaN               NaN
# 31       NaN        NaN  NaN     NaN        NaN               NaN
